# %% [markdown]
# # MESTRADO - DOUGLAS DE ANDRADE DE ALMEIDA
#
# ## TÍTULO: ALGORITMO DE PREDIÇÃO DE DESENVOLVIMENTO DE RESISTÊNCIA DO VÍRUS DA HEPATITE C (HCV) AOS ANTIVIRAIS DE AÇÃO DIRETA
#
# ## FEVEREIRO/2018

# %% [markdown]
# #### Adding paths

# %%
import sys
sys.path.append('../')
sys.path.append('../Scripts/')

# %% [markdown]
# ### Libraries

# %%
import collections
import json
from Global_Variables import *
import Aux_Functions as af
import numpy as np
import pandas as pd

# %%
geno

# %% [markdown]
# ### Open fasta file & Acession Number e Sequence

# %%
Datasets_Reference = [("NS5A_1b_06.03.2018.aln","1b"),
                     ("NS5A_GEN1a_02.05.16","1a"),
                     ("NS5A_GEN3_05.05.16","3")]

# %%
genotype_1b = af.fasta_to_dict("../Data/" + "NS5A_1b_06.03.2018.aln")
genotype_1b_codons = {}
for sequence in genotype_1b.items():
    genotype_1b_codons[sequence[0]] = af.sequence_codons(sequence[1])

# %% [markdown]
# #### Contar as frequências

# %%
df = pd.DataFrame(data=genotype_1b_codons)
df = df.transpose()
df_frequency = df.apply(pd.value_counts)
df_frequency = df_frequency.apply(lambda x: x/len(df))

# %%
df_frequency
# Out:
#            28        29        30        31        32        54        92  \
# AAA       NaN       NaN  0.002427       NaN       NaN       NaN       NaN
# AAC       NaN       NaN       NaN       NaN       NaN  0.008495       NaN
# AAG       NaN       NaN  0.001214       NaN       NaN       NaN       NaN
# AAT       NaN       NaN       NaN       NaN       NaN  0.038835       NaN
# ACA       NaN       NaN       NaN       NaN       NaN       NaN  0.004854
# ACG       NaN       NaN       NaN       NaN       NaN       NaN  0.008495
# AGG       NaN       NaN  0.004854       NaN       NaN       NaN       NaN
# ATA       NaN       NaN       NaN  0.002427       NaN       NaN       NaN
# ATG  0.016990       NaN  0.001214  0.033981       NaN       NaN       NaN
# CAA       NaN       NaN  0.003641       NaN       NaN  0.410194       NaN
# CAC       NaN       NaN       NaN       NaN       NaN  0.156553       NaN
# CAG       NaN       NaN  0.037621       NaN       NaN  0.252427       NaN
# CAR       NaN       NaN       NaN       NaN       NaN  0.002427       NaN
# CAT       NaN       NaN       NaN       NaN       NaN  0.108010       NaN
# CCA       NaN  0.167476       NaN  0.001214  0.094660       NaN       NaN
# CCC       NaN  0.004854       NaN       NaN  0.013350       NaN       NaN
# CCG  0.001214  0.822816       NaN       NaN  0.888350       NaN       NaN
# CCT       NaN  0.003641       NaN       NaN  0.003641       NaN       NaN
# CGA       NaN       NaN  0.131068       NaN       NaN       NaN       NaN
# CGC       NaN       NaN  0.004854       NaN       NaN       NaN       NaN
# CGG       NaN       NaN  0.810680       NaN       NaN       NaN       NaN
# CGT       NaN       NaN  0.002427       NaN       NaN       NaN       NaN
# CTA  0.018204       NaN       NaN  0.086165       NaN  0.003641       NaN
# CTC  0.007282       NaN       NaN  0.001214       NaN  0.001214       NaN
# CTG  0.927184       NaN       NaN  0.110437       NaN       NaN       NaN
# CTT  0.002427       NaN       NaN  0.003641       NaN       NaN       NaN
# GAA       NaN       NaN       NaN       NaN       NaN  0.001214       NaN
# GCA       NaN       NaN       NaN       NaN       NaN       NaN  0.570388
# GCC       NaN       NaN       NaN       NaN       NaN       NaN  0.003641
# GCG       NaN       NaN       NaN       NaN       NaN       NaN  0.393204
# GCT       NaN       NaN       NaN       NaN       NaN       NaN  0.010922
# GGA       NaN       NaN       NaN       NaN       NaN       NaN  0.002427
# GTA       NaN       NaN       NaN       NaN       NaN       NaN  0.001214
# GTG  0.003641       NaN       NaN       NaN       NaN       NaN  0.003641
# TAC       NaN       NaN       NaN       NaN       NaN  0.006068       NaN
# TAT       NaN       NaN       NaN       NaN       NaN  0.009709       NaN
# TCA       NaN  0.001214       NaN       NaN       NaN       NaN  0.001214
# TGC       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# TTA       NaN       NaN       NaN  0.445388       NaN  0.001214       NaN
# TTG  0.023058       NaN       NaN  0.315534       NaN       NaN       NaN
#
#            93
# AAA       NaN
# AAC       NaN
# AAG       NaN
# AAT       NaN
# ACA       NaN
# ACG       NaN
# AGG       NaN
# ATA       NaN
# ATG       NaN
# CAA       NaN
# CAC  0.037621
# CAG       NaN
# CAR       NaN
# CAT       NaN
# CCA       NaN
# CCC       NaN
# CCG       NaN
# CCT       NaN
# CGA       NaN
# CGC       NaN
# CGG       NaN
# CGT       NaN
# CTA       NaN
# CTC       NaN
# CTG       NaN
# CTT       NaN
# GAA       NaN
# GCA       NaN
# GCC       NaN
# GCG       NaN
# GCT       NaN
# GGA       NaN
# GTA       NaN
# GTG       NaN
# TAC  0.945388
# TAT  0.015777
# TCA       NaN
# TGC  0.001214
# TTA       NaN
# TTG       NaN

# %% [markdown]
# #### Tabela

# %%
df_codons = pd.DataFrame(columns=["Genotype", "Position", "Codon", "Codon Usage", "Frequency"])

# %%
df_codons
# Out:
# Empty DataFrame
# Columns: [Genotype, Position, Codon, Codon Usage, Frequency]
# Index: []
