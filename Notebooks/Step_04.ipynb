# %%
import sys
sys.path.append('../')
sys.path.append('../Scripts/')

# %%
import pandas as pd
from Global_Variables import *
import Aux_Functions as af

# %%
step3 = pd.read_csv("../Outputs/Step_03.csv", sep=";")
dataset_global = pd.read_csv("../Outputs/CodonUsage_Frequency.csv", sep=";")
dataset_global
# Out:
#     Genotype  Position Codon  Frequency  HCV-G1
# 0         1b        24   AAA   0.000000    0.32
# 1         1b        28   AAA   0.000000    0.32
# 2         1b        29   AAA   0.000000    0.32
# 3         1b        30   AAA   0.002427    0.32
# 4         1b        31   AAA   0.000000    0.32
# 5         1b        32   AAA   0.000000    0.32
# 6         1b        54   AAA   0.000000    0.32
# 7         1b        58   AAA   0.000000    0.32
# 8         1b        92   AAA   0.000000    0.32
# 9         1b        93   AAA   0.000000    0.32
# 10        1b        24   AAC   0.000000    0.71
# 11        1b        28   AAC   0.000000    0.71
# 12        1b        29   AAC   0.000000    0.71
# 13        1b        30   AAC   0.000000    0.71
# 14        1b        31   AAC   0.000000    0.71
# 15        1b        32   AAC   0.000000    0.71
# 16        1b        54   AAC   0.008495    0.71
# 17        1b        58   AAC   0.000000    0.71
# 18        1b        92   AAC   0.000000    0.71
# 19        1b        93   AAC   0.000000    0.71
# 20        1b        24   AAG   0.009709    0.68
# 21        1b        28   AAG   0.000000    0.68
# 22        1b        29   AAG   0.000000    0.68
# 23        1b        30   AAG   0.001214    0.68
# 24        1b        31   AAG   0.000000    0.68
# 25        1b        32   AAG   0.000000    0.68
# 26        1b        54   AAG   0.000000    0.68
# 27        1b        58   AAG   0.000000    0.68
# 28        1b        92   AAG   0.000000    0.68
# 29        1b        93   AAG   0.000000    0.68
# ..       ...       ...   ...        ...     ...
# 610       1b        24   TGT   0.000000    0.31
# 611       1b        28   TGT   0.000000    0.31
# 612       1b        29   TGT   0.000000    0.31
# 613       1b        30   TGT   0.000000    0.31
# 614       1b        31   TGT   0.000000    0.31
# 615       1b        32   TGT   0.000000    0.31
# 616       1b        54   TGT   0.000000    0.31
# 617       1b        58   TGT   0.000000    0.31
# 618       1b        92   TGT   0.000000    0.31
# 619       1b        93   TGT   0.000000    0.31
# 620       1b        24   TGA   0.000000    1.00
# 621       1b        28   TGA   0.000000    1.00
# 622       1b        29   TGA   0.000000    1.00
# 623       1b        30   TGA   0.000000    1.00
# 624       1b        31   TGA   0.000000    1.00
# 625       1b        32   TGA   0.000000    1.00
# 626       1b        54   TGA   0.000000    1.00
# 627       1b        58   TGA   0.000000    1.00
# 628       1b        92   TGA   0.000000    1.00
# 629       1b        93   TGA   0.000000    1.00
# 630       1b        24   TGG   0.000000    1.00
# 631       1b        28   TGG   0.000000    1.00
# 632       1b        29   TGG   0.000000    1.00
# 633       1b        30   TGG   0.000000    1.00
# 634       1b        31   TGG   0.000000    1.00
# 635       1b        32   TGG   0.000000    1.00
# 636       1b        54   TGG   0.000000    1.00
# 637       1b        58   TGG   0.000000    1.00
# 638       1b        92   TGG   0.000000    1.00
# 639       1b        93   TGG   0.000000    1.00
#
# [640 rows x 5 columns]

# %%
def add_features(row):


    for item in Codon_Resistente_List:
        # Criando a linha de barreira genética
        gb = af.genetic_barrier(row[item],row['Codon'])
        column_name = "gb_" + item[-2:]
        row[column_name] = gb
        # Criando a linha de frequencia
        df = dataset_global[(dataset_global['Genotype'] == row['Genotype']) 
                             & (dataset_global['Position'] == row['Position']) 
                             & (dataset_global['Codon'] == row[item])]
        if df.shape[0] > 0:
            # freq 
            freq = df['Frequency'].values[0]
            column_name = "freq_" + item[-2:]
            row[column_name] = freq
            
            # codon_usage
            codon_usage = df['HCV-G1'].values[0]
            column_name = "codon_usage_" + item[-2:]
            row[column_name] = codon_usage
        else:
            freq = "-"
            column_name = "freq_" + item[-2:]
            row[column_name] = 0
            
            codon_usage = "-"
            column_name = "codon_usage_" + item[-2:]
            row[column_name] = 0
        
            
            
    return row

# %%
modstep3 = step3.apply(lambda x: add_features(x), axis=1)
modstep3
modstep3 = modstep3.fillna("-") # Not a Number values into 0

# %%
df = dataset_global[
    (dataset_global['Genotype'] == '1b') 
    & (dataset_global['Position'] == 28)
    & (dataset_global['Codon'] == 'CTG')
]
#dataset_global.dtypes

# %%
modstep3
# Out:
#     Sequence Genotype  Position Codon Drug Codon_Resistente_01  \
# 0   MXYZPTLK       1b        24   CAG    -                   -
# 1   MXYZPTLK       1b        28   CTG  DCV                 ATG
# 2   MXYZPTLK       1b        28   CTG  EBR                 ATG
# 3   MXYZPTLK       1b        28   CTG  LDV                 ATG
# 4   MXYZPTLK       1b        28   CTG  OMV                 ATG
# 5   MXYZPTLK       1b        29   CCA    -                   -
# 6   MXYZPTLK       1b        30   CGG  DCV                 CAA
# 7   MXYZPTLK       1b        30   CGG  EBR                 CAA
# 8   MXYZPTLK       1b        30   CGG  LDV                 CAA
# 9   MXYZPTLK       1b        30   CGG  OMV                 CAA
# 10  MXYZPTLK       1b        31   TTG  DCV                 ATG
# 11  MXYZPTLK       1b        31   TTG  PIB                 ATG
# 12  MXYZPTLK       1b        31   TTG  EBR                 GTA
# 13  MXYZPTLK       1b        31   TTG  LDV                 GTA
# 14  MXYZPTLK       1b        31   TTG  OMV                 GTA
# 15  MXYZPTLK       1b        31   TTG  VEL                 GTA
# 16  MXYZPTLK       1b        32   CCG    -                   -
# 17  MXYZPTLK       1b        54   CAC    -                   -
# 18  MXYZPTLK       1b        58   CCA  DCV                 AGC
# 19  MXYZPTLK       1b        92   GCG  LDV                 ACA
# 20  MXYZPTLK       1b        93   TAC  DCV                 CAC
# 21  MXYZPTLK       1b        93   TAC  EBR                 CAC
# 22  MXYZPTLK       1b        93   TAC  LDV                 CAC
# 23  MXYZPTLK       1b        93   TAC  OMV                 CAC
# 24  MXYZPTLK       1b        93   TAC  PIB                 CAC
# 25  MXYZPTLK       1b        93   TAC  VEL                 CAC
#
#    Codon_Resistente_02 Codon_Resistente_03 Codon_Resistente_04  \
# 0                    -                   -                   -
# 1                    -                   -                   -
# 2                    -                   -                   -
# 3                    -                   -                   -
# 4                    -                   -                   -
# 5                    -                   -                   -
# 6                  CAG                   -                   -
# 7                  CAG                   -                   -
# 8                  CAG                   -                   -
# 9                  CAG                   -                   -
# 10                 TTC                 TTT                 GTA
# 11                   -                   -                   -
# 12                 GTC                 GTG                 GTT
# 13                 GTC                 GTG                 GTT
# 14                 GTC                 GTG                 GTT
# 15                 GTC                 GTG                 GTT
# 16                   -                   -                   -
# 17                   -                   -                   -
# 18                 AGT                 TCA                 TCC
# 19                 ACC                 ACG                 ACT
# 20                 CAT                   -                   -
# 21                 CAT                   -                   -
# 22                 CAT                   -                   -
# 23                 CAT                   -                   -
# 24                 CAT                   -                   -
# 25                 CAT                   -                   -
#
#    Codon_Resistente_05  ... codon_usage_09 gb_10 freq_10 codon_usage_10 gb_11  \
# 0                    -  ...           0.00     -     0.0           0.00     -
# 1                    -  ...           0.00     -     0.0           0.00     -
# 2                    -  ...           0.00     -     0.0           0.00     -
# 3                    -  ...           0.00     -     0.0           0.00     -
# 4                    -  ...           0.00     -     0.0           0.00     -
# 5                    -  ...           0.00     -     0.0           0.00     -
# 6                    -  ...           0.00     -     0.0           0.00     -
# 7                    -  ...           0.00     -     0.0           0.00     -
# 8                    -  ...           0.00     -     0.0           0.00     -
# 9                    -  ...           0.00     -     0.0           0.00     -
# 10                 GTC  ...           0.00     -     0.0           0.00     -
# 11                   -  ...           0.00     -     0.0           0.00     -
# 12                 TTC  ...           0.00     -     0.0           0.00     -
# 13                 TTC  ...           0.00     -     0.0           0.00     -
# 14                 TTC  ...           0.00     -     0.0           0.00     -
# 15                 ATG  ...           0.00     -     0.0           0.00     -
# 16                   -  ...           0.00     -     0.0           0.00     -
# 17                   -  ...           0.00     -     0.0           0.00     -
# 18                 TCG  ...           0.32   3.5     0.0           0.17     2
# 19                   -  ...           0.00     -     0.0           0.00     -
# 20                   -  ...           0.00     -     0.0           0.00     -
# 21                   -  ...           0.00     -     0.0           0.00     -
# 22                   -  ...           0.00     -     0.0           0.00     -
# 23                   -  ...           0.00     -     0.0           0.00     -
# 24                   -  ...           0.00     -     0.0           0.00     -
# 25                   -  ...           0.00     -     0.0           0.00     -
#
#      freq_11 codon_usage_11 gb_12  freq_12  codon_usage_12
# 0   0.000000           0.00     -      0.0            0.00
# 1   0.000000           0.00     -      0.0            0.00
# 2   0.000000           0.00     -      0.0            0.00
# 3   0.000000           0.00     -      0.0            0.00
# 4   0.000000           0.00     -      0.0            0.00
# 5   0.000000           0.00     -      0.0            0.00
# 6   0.000000           0.00     -      0.0            0.00
# 7   0.000000           0.00     -      0.0            0.00
# 8   0.000000           0.00     -      0.0            0.00
# 9   0.000000           0.00     -      0.0            0.00
# 10  0.000000           0.00     -      0.0            0.00
# 11  0.000000           0.00     -      0.0            0.00
# 12  0.000000           0.00     -      0.0            0.00
# 13  0.000000           0.00     -      0.0            0.00
# 14  0.000000           0.00     -      0.0            0.00
# 15  0.000000           0.00     -      0.0            0.00
# 16  0.000000           0.00     -      0.0            0.00
# 17  0.000000           0.00     -      0.0            0.00
# 18  0.001214           0.03     3      0.0            0.12
# 19  0.000000           0.00     -      0.0            0.00
# 20  0.000000           0.00     -      0.0            0.00
# 21  0.000000           0.00     -      0.0            0.00
# 22  0.000000           0.00     -      0.0            0.00
# 23  0.000000           0.00     -      0.0            0.00
# 24  0.000000           0.00     -      0.0            0.00
# 25  0.000000           0.00     -      0.0            0.00
#
# [26 rows x 53 columns]

# %%
modstep3.to_csv("teste.csv", sep=";", index=False)
