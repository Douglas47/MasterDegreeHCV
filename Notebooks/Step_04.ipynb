# %%
import sys
sys.path.append('../')
sys.path.append('../Scripts/')

# %%
import pandas as pd
from Global_Variables import *
import Aux_Functions as af

# %%
step3 = pd.read_csv("../Outputs/Step_03.csv", sep=";")
dataset_global = pd.read_csv("../Outputs/CodonUsage_Frequency.csv", sep=";")
dataset_global
# Out:
#     Genotype  Position Codon  Frequency  HCV-G1
# 0         1b        24   AAA   0.000000    0.32
# 1         1b        28   AAA   0.000000    0.32
# 2         1b        29   AAA   0.000000    0.32
# 3         1b        30   AAA   0.002427    0.32
# 4         1b        31   AAA   0.000000    0.32
# ..       ...       ...   ...        ...     ...
# 405       1b        32   TTG   0.000000    0.12
# 406       1b        54   TTG   0.000000    0.12
# 407       1b        58   TTG   0.000000    0.12
# 408       1b        92   TTG   0.000000    0.12
# 409       1b        93   TTG   0.000000    0.12
#
# [410 rows x 5 columns]

# %%
def add_features(row):


    for item in Codon_Resistente_List:
        # Criando a linha de barreira genética
        gb = af.genetic_barrier(row[item],row['Codon'])
        column_name = "gb_" + item[-2:]
        row[column_name] = gb
        # Criando a linha de frequencia
        df = dataset_global[(dataset_global['Genotype'] == row['Genotype']) 
                             & (dataset_global['Position'] == row['Position']) 
                             & (dataset_global['Codon'] == row[item])]
        if df.shape[0] > 0:
            # freq 
            freq = df['Frequency'].values[0]
            column_name = "freq_" + item[-2:]
            row[column_name] = freq
            
            # codon_usage
            codon_usage = df['HCV-G1'].values[0]
            column_name = "codon_usage_" + item[-2:]
            row[column_name] = codon_usage
        else:
            
            column_name = "freq_" + item[-2:]
            row[column_name] = 0
            
            column_name = "codon_usage_" + item[-2:]
            row[column_name] = 0
        
            
            
    return row

# %%
modstep3 = step3.apply(lambda x: add_features(x), axis=1)
modstep3
# Out:
#     Sequence Genotype  Position Codon Drug Codon_Resistente_01  \
# 0   MXYZPTLK       1b        24   CAG  NaN                 NaN
# 1   MXYZPTLK       1b        28   CTG  DCV                 ATG
# 2   MXYZPTLK       1b        28   CTG  EBR                 ATG
# 3   MXYZPTLK       1b        28   CTG  LDV                 ATG
# 4   MXYZPTLK       1b        28   CTG  OMV                 ATG
# 5   MXYZPTLK       1b        29   CCA  NaN                 NaN
# 6   MXYZPTLK       1b        30   CGG  DCV                 CAA
# 7   MXYZPTLK       1b        30   CGG  EBR                 CAA
# 8   MXYZPTLK       1b        30   CGG  LDV                 CAA
# 9   MXYZPTLK       1b        30   CGG  OMV                 CAA
# 10  MXYZPTLK       1b        31   TTG  DCV                 ATG
# 11  MXYZPTLK       1b        31   TTG  PIB                 ATG
# 12  MXYZPTLK       1b        31   TTG  EBR                 GTA
# 13  MXYZPTLK       1b        31   TTG  LDV                 GTA
# 14  MXYZPTLK       1b        31   TTG  OMV                 GTA
# 15  MXYZPTLK       1b        31   TTG  VEL                 GTA
# 16  MXYZPTLK       1b        32   CCG  NaN                 NaN
# 17  MXYZPTLK       1b        54   CAC  NaN                 NaN
# 18  MXYZPTLK       1b        58   CCA  DCV                 AGC
# 19  MXYZPTLK       1b        92   GCG  LDV                 ACA
# 20  MXYZPTLK       1b        93   TAC  DCV                 CAC
# 21  MXYZPTLK       1b        93   TAC  EBR                 CAC
# 22  MXYZPTLK       1b        93   TAC  LDV                 CAC
# 23  MXYZPTLK       1b        93   TAC  OMV                 CAC
# 24  MXYZPTLK       1b        93   TAC  PIB                 CAC
# 25  MXYZPTLK       1b        93   TAC  VEL                 CAC
#
#    Codon_Resistente_02 Codon_Resistente_03 Codon_Resistente_04  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  CAG                 NaN                 NaN
# 7                  CAG                 NaN                 NaN
# 8                  CAG                 NaN                 NaN
# 9                  CAG                 NaN                 NaN
# 10                 TTC                 TTT                 GTA
# 11                 NaN                 NaN                 NaN
# 12                 GTC                 GTG                 GTT
# 13                 GTC                 GTG                 GTT
# 14                 GTC                 GTG                 GTT
# 15                 GTC                 GTG                 GTT
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 AGT                 TCA                 TCC
# 19                 ACC                 ACG                 ACT
# 20                 CAT                 NaN                 NaN
# 21                 CAT                 NaN                 NaN
# 22                 CAT                 NaN                 NaN
# 23                 CAT                 NaN                 NaN
# 24                 CAT                 NaN                 NaN
# 25                 CAT                 NaN                 NaN
#
#    Codon_Resistente_05  ... codon_usage_09 gb_10 freq_10 codon_usage_10 gb_11  \
# 0                  NaN  ...           0.00   0.0     0.0           0.00     0
# 1                  NaN  ...           0.00   0.0     0.0           0.00     0
# 2                  NaN  ...           0.00   0.0     0.0           0.00     0
# 3                  NaN  ...           0.00   0.0     0.0           0.00     0
# 4                  NaN  ...           0.00   0.0     0.0           0.00     0
# 5                  NaN  ...           0.00   0.0     0.0           0.00     0
# 6                  NaN  ...           0.00   0.0     0.0           0.00     0
# 7                  NaN  ...           0.00   0.0     0.0           0.00     0
# 8                  NaN  ...           0.00   0.0     0.0           0.00     0
# 9                  NaN  ...           0.00   0.0     0.0           0.00     0
# 10                 GTC  ...           0.00   0.0     0.0           0.00     0
# 11                 NaN  ...           0.00   0.0     0.0           0.00     0
# 12                 TTC  ...           0.00   0.0     0.0           0.00     0
# 13                 TTC  ...           0.00   0.0     0.0           0.00     0
# 14                 TTC  ...           0.00   0.0     0.0           0.00     0
# 15                 ATG  ...           0.00   0.0     0.0           0.00     0
# 16                 NaN  ...           0.00   0.0     0.0           0.00     0
# 17                 NaN  ...           0.00   0.0     0.0           0.00     0
# 18                 TCG  ...           0.32   3.5     0.0           0.17     2
# 19                 NaN  ...           0.00   0.0     0.0           0.00     0
# 20                 NaN  ...           0.00   0.0     0.0           0.00     0
# 21                 NaN  ...           0.00   0.0     0.0           0.00     0
# 22                 NaN  ...           0.00   0.0     0.0           0.00     0
# 23                 NaN  ...           0.00   0.0     0.0           0.00     0
# 24                 NaN  ...           0.00   0.0     0.0           0.00     0
# 25                 NaN  ...           0.00   0.0     0.0           0.00     0
#
#      freq_11 codon_usage_11  gb_12  freq_12  codon_usage_12
# 0   0.000000           0.00      0      0.0            0.00
# 1   0.000000           0.00      0      0.0            0.00
# 2   0.000000           0.00      0      0.0            0.00
# 3   0.000000           0.00      0      0.0            0.00
# 4   0.000000           0.00      0      0.0            0.00
# 5   0.000000           0.00      0      0.0            0.00
# 6   0.000000           0.00      0      0.0            0.00
# 7   0.000000           0.00      0      0.0            0.00
# 8   0.000000           0.00      0      0.0            0.00
# 9   0.000000           0.00      0      0.0            0.00
# 10  0.000000           0.00      0      0.0            0.00
# 11  0.000000           0.00      0      0.0            0.00
# 12  0.000000           0.00      0      0.0            0.00
# 13  0.000000           0.00      0      0.0            0.00
# 14  0.000000           0.00      0      0.0            0.00
# 15  0.000000           0.00      0      0.0            0.00
# 16  0.000000           0.00      0      0.0            0.00
# 17  0.000000           0.00      0      0.0            0.00
# 18  0.001214           0.03      3      0.0            0.12
# 19  0.000000           0.00      0      0.0            0.00
# 20  0.000000           0.00      0      0.0            0.00
# 21  0.000000           0.00      0      0.0            0.00
# 22  0.000000           0.00      0      0.0            0.00
# 23  0.000000           0.00      0      0.0            0.00
# 24  0.000000           0.00      0      0.0            0.00
# 25  0.000000           0.00      0      0.0            0.00
#
# [26 rows x 53 columns]

# %%
df = dataset_global[
    (dataset_global['Genotype'] == '1b') 
    & (dataset_global['Position'] == 28)
    & (dataset_global['Codon'] == 'CTG')
]
#dataset_global.dtypes

# %%
df['Frequency'].values[0]
# Out:
# 0.9271844660194176

# %%
modstep3.to_csv("teste.csv", sep=";", index=False)

# %%
step3
# Out:
#     Sequence Genotype  Position Codon Drug Codon_Resistente_01  \
# 0   MXYZPTLK       1b        24   CAG  NaN                 NaN
# 1   MXYZPTLK       1b        28   CTG  DCV                 ATG
# 2   MXYZPTLK       1b        28   CTG  EBR                 ATG
# 3   MXYZPTLK       1b        28   CTG  LDV                 ATG
# 4   MXYZPTLK       1b        28   CTG  OMV                 ATG
# 5   MXYZPTLK       1b        29   CCA  NaN                 NaN
# 6   MXYZPTLK       1b        30   CGG  DCV                 CAA
# 7   MXYZPTLK       1b        30   CGG  EBR                 CAA
# 8   MXYZPTLK       1b        30   CGG  LDV                 CAA
# 9   MXYZPTLK       1b        30   CGG  OMV                 CAA
# 10  MXYZPTLK       1b        31   TTG  DCV                 ATG
# 11  MXYZPTLK       1b        31   TTG  PIB                 ATG
# 12  MXYZPTLK       1b        31   TTG  EBR                 GTA
# 13  MXYZPTLK       1b        31   TTG  LDV                 GTA
# 14  MXYZPTLK       1b        31   TTG  OMV                 GTA
# 15  MXYZPTLK       1b        31   TTG  VEL                 GTA
# 16  MXYZPTLK       1b        32   CCG  NaN                 NaN
# 17  MXYZPTLK       1b        54   CAC  NaN                 NaN
# 18  MXYZPTLK       1b        58   CCA  DCV                 AGC
# 19  MXYZPTLK       1b        92   GCG  LDV                 ACA
# 20  MXYZPTLK       1b        93   TAC  DCV                 CAC
# 21  MXYZPTLK       1b        93   TAC  EBR                 CAC
# 22  MXYZPTLK       1b        93   TAC  LDV                 CAC
# 23  MXYZPTLK       1b        93   TAC  OMV                 CAC
# 24  MXYZPTLK       1b        93   TAC  PIB                 CAC
# 25  MXYZPTLK       1b        93   TAC  VEL                 CAC
#
#    Codon_Resistente_02 Codon_Resistente_03 Codon_Resistente_04  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  CAG                 NaN                 NaN
# 7                  CAG                 NaN                 NaN
# 8                  CAG                 NaN                 NaN
# 9                  CAG                 NaN                 NaN
# 10                 TTC                 TTT                 GTA
# 11                 NaN                 NaN                 NaN
# 12                 GTC                 GTG                 GTT
# 13                 GTC                 GTG                 GTT
# 14                 GTC                 GTG                 GTT
# 15                 GTC                 GTG                 GTT
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 AGT                 TCA                 TCC
# 19                 ACC                 ACG                 ACT
# 20                 CAT                 NaN                 NaN
# 21                 CAT                 NaN                 NaN
# 22                 CAT                 NaN                 NaN
# 23                 CAT                 NaN                 NaN
# 24                 CAT                 NaN                 NaN
# 25                 CAT                 NaN                 NaN
#
#    Codon_Resistente_05 Codon_Resistente_06 Codon_Resistente_07  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 GTC                 GTG                 GTT
# 11                 NaN                 NaN                 NaN
# 12                 TTC                 TTT                 ATG
# 13                 TTC                 TTT                 ATG
# 14                 TTC                 TTT                 ATG
# 15                 ATG                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 TCG                 TCT                 CTA
# 19                 NaN                 NaN                 NaN
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22                 NaN                 NaN                 NaN
# 23                 NaN                 NaN                 NaN
# 24                 NaN                 NaN                 NaN
# 25                 NaN                 NaN                 NaN
#
#    Codon_Resistente_08 Codon_Resistente_09 Codon_Resistente_10  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 CTC                 CTG                 CTT
# 19                 NaN                 NaN                 NaN
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22                 NaN                 NaN                 NaN
# 23                 NaN                 NaN                 NaN
# 24                 NaN                 NaN                 NaN
# 25                 NaN                 NaN                 NaN
#
#    Codon_Resistente_11 Codon_Resistente_12
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# 5                  NaN                 NaN
# 6                  NaN                 NaN
# 7                  NaN                 NaN
# 8                  NaN                 NaN
# 9                  NaN                 NaN
# 10                 NaN                 NaN
# 11                 NaN                 NaN
# 12                 NaN                 NaN
# 13                 NaN                 NaN
# 14                 NaN                 NaN
# 15                 NaN                 NaN
# 16                 NaN                 NaN
# 17                 NaN                 NaN
# 18                 TTA                 TTG
# 19                 NaN                 NaN
# 20                 NaN                 NaN
# 21                 NaN                 NaN
# 22                 NaN                 NaN
# 23                 NaN                 NaN
# 24                 NaN                 NaN
# 25                 NaN                 NaN
